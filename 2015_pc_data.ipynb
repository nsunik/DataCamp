# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import seaborn as sns
df_2015=pd.read_csv(r'C:\Users\DELL\Downloads\2015-building-energy-benchmarking.csv')

# %%
#basic data analysis,quick view of data set
#showes first five rows of the data se
df_2015.head()
#47 columns
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# ...

# %%
#summary statistics
df_2015.describe()
# Out:
#        OSEBuildingID  DataYear  CouncilDistrictCode    YearBuilt  \
# count    3340.000000    3340.0          3340.000000  3340.000000
# mean    20522.168263    2015.0             4.450898  1967.624850
# std     11511.515874       0.0             2.127203    32.949847
# min         1.000000    2015.0             1.000000  1900.000000
# 25%     19921.750000    2015.0             3.000000  1947.000000
# 50%     22977.000000    2015.0             4.000000  1973.000000
# 75%     25748.000000    2015.0             7.000000  1996.000000
# max     50059.000000    2015.0             7.000000  2015.000000
#
#        NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# count        3340.000000     3332.000000      3.340000e+03
# mean            1.035629        4.682173      9.077289e+04
# std             0.784463        5.458460      1.493058e+05
# min             1.000000        0.000000      2.000000e+04
# 25%             1.000000        2.000000      2.848700e+04
# ...

# %%
#nature of dataset columns (attributes).
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
# Inspect missing values in the dataset
print(df_2015.isnull().values.sum())
# Out:
# 26512

# %%
#drop the columns which has lot of missing values
df_2015.drop(['Comment' ,'Outlier','2010 Census Tracts','City Council Districts','ThirdLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','YearsENERGYSTARCertified'],axis=1, inplace=True)

# %%
df_2015.info()
#40 columns
#7cols droped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
# Inspect missing values in the dataset(after droping the columns )
print(df_2015.isnull().values.sum())
#4896
# Out:
# 4896

# %%
# one hot encoding on BuildingType
df_dummy_build= pd.get_dummies(df_2015.BuildingType)
#df = pd.concat([df, df_dummy], axis = 1)

# %%
df_dummy_build
# Out:
#       Campus  Multifamily HR (10+)  Multifamily LR (1-4)  \
# 0          0                     0                     0
# 1          0                     0                     0
# 2          0                     0                     0
# 3          0                     0                     0
# 4          0                     0                     0
# ...      ...                   ...                   ...
# 3335       0                     0                     1
# 3336       0                     0                     0
# 3337       0                     1                     0
# 3338       0                     0                     1
# 3339       0                     0                     1
#
#       Multifamily MR (5-9)  NonResidential  Nonresidential COS  \
# 0                        0               1                   0
# 1                        0               1                   0
# 2                        0               1                   0
# ...

# %%
#df_2015=pd.concat([df_2015,df_dummy_build], axis=1)

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
#sort the column
df_2015=df_2015.reindex(sorted(df_2015.columns), axis=1)

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   3340 non-null   object
#  1   ComplianceStatus                                               3340 non-null   object
#  2   CouncilDistrictCode                                            3340 non-null   int64
#  3   DataYear                                                       3340 non-null   int64
#  4   DefaultData                                                    3339 non-null   object
#  5   ENERGYSTARScore                                                2560 non-null   float64
#  6   Electricity(kBtu)                                              3330 non-null   float64
# ...

# %%
#describe the "ENERGYSTARScore" -basic statistical details
df_2015["ENERGYSTARScore"].describe()
# Out:
# count    3340.000000
# mean       67.894141
# std        23.771778
# min         1.000000
# 25%        60.000000
# 50%        67.894141
# 75%        86.000000
# max       100.000000
# Name: ENERGYSTARScore, dtype: float64

# %%
df_2015["ENERGYSTARScore"].fillna(df_2015["ENERGYSTARScore"].mean() ,inplace=True)

# %%
df_2015["Electricity(kBtu)"].fillna(df_2015["Electricity(kBtu)"].mean(),inplace=True)
df_2015["Electricity(kWh)"].fillna(df_2015["Electricity(kWh)"].mean(),inplace=True)

# %%
df_2015["GHGEmissions(MetricTonsCO2e)"].fillna(df_2015["GHGEmissions(MetricTonsCO2e)"].mean(),inplace=True)
df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"].fillna(df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"].mean(),inplace=True)

# %%
df_2015["LargestPropertyUseType"].fillna(df_2015["LargestPropertyUseType"].mode(), inplace = True)
df_2015["LargestPropertyUseTypeGFA"].fillna(df_2015["LargestPropertyUseTypeGFA"].mean(), inplace = True)

# %%
df_2015["ListOfAllPropertyUseTypes"].fillna(df_2015["ListOfAllPropertyUseTypes"].mode(), inplace = True)

# %%
df_2015["NaturalGas(kBtu)"].fillna(df_2015["NaturalGas(kBtu)"].mean(), inplace = True)
df_2015["NaturalGas(therms)"].fillna(df_2015["NaturalGas(therms)"].mean(), inplace = True)

# %%
df_2015["NumberofBuildings"].fillna(df_2015["NumberofBuildings"].mean(), inplace = True)
df_2015["OtherFuelUse(kBtu)"].fillna(df_2015["OtherFuelUse(kBtu)"].mean(), inplace = True)

# %%
df_2015["SPD Beats"].fillna(df_2015["SPD Beats"].mean(),inplace = True)

# %%
df_2015["Seattle Police Department Micro Community Policing Plan Areas"].fillna(df_2015["Seattle Police Department Micro Community Policing Plan Areas"].mode(), inplace = True)

# %%
df_2015["SecondLargestPropertyUseType"].fillna(df_2015["SecondLargestPropertyUseType"].mode(), inplace = True)
df_2015["SecondLargestPropertyUseTypeGFA"].fillna(df_2015["SecondLargestPropertyUseTypeGFA"].mean(), inplace = True)

# %%
df_2015["SecondLargestPropertyUseType"].fillna(df_2015["SecondLargestPropertyUseType"].mode(), inplace = True)

# %%
df_2015["SiteEUI(kBtu/sf)"].fillna(df_2015["SiteEUI(kBtu/sf)"].mean(), inplace = True)
df_2015["SiteEUIWN(kBtu/sf)"].fillna(df_2015["SiteEUIWN(kBtu/sf)"].mean(), inplace = True)
df_2015["SteamUse(kBtu)"].fillna(df_2015["SteamUse(kBtu)"].mean(), inplace = True)
df_2015["SiteEnergyUse(kBtu)"].fillna(df_2015["SiteEnergyUse(kBtu)"].mean(), inplace = True)
df_2015["SiteEnergyUseWN(kBtu)"].fillna(df_2015["SiteEnergyUseWN(kBtu)"].mean(), inplace = True)
df_2015["SourceEUI(kBtu/sf)"].fillna(df_2015["SourceEUI(kBtu/sf)"].mean(), inplace = True)
df_2015["SourceEUIWN(kBtu/sf)"].fillna(df_2015["SourceEUIWN(kBtu/sf)"].mean(), inplace = True)

# %%
df_2015["TaxParcelIdentificationNumber"].fillna(df_2015["TaxParcelIdentificationNumber"].mode(), inplace = True)

# %%
df_2015["ListOfAllPropertyUseTypes"].fillna(df_2015["ListOfAllPropertyUseTypes"].mode(), inplace = True)

# %%
df_2015["NumberofFloors"].fillna(df_2015["NumberofFloors"].mean(), inplace = True)

# %%
print(df_2015.isnull().values.sum())
# Out:
# 2048

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   3340 non-null   object
#  1   ComplianceStatus                                               3340 non-null   object
#  2   CouncilDistrictCode                                            3340 non-null   int64
#  3   DataYear                                                       3340 non-null   int64
#  4   DefaultData                                                    3339 non-null   object
#  5   ENERGYSTARScore                                                3340 non-null   float64
#  6   Electricity(kBtu)                                              3340 non-null   float64
# ...

# %%
df_2015["SecondLargestPropertyUseType"].fillna(df_2015["SecondLargestPropertyUseType"].mode(), inplace=True)

# %%
#To select  numeric types and object types
df_2015_num=df_2015.select_dtypes(np.number)
df_2015_obj=df_2015.select_dtypes('object')

# %%
df_2015_num.columns
# Out:
# Index(['CouncilDistrictCode', 'DataYear', 'ENERGYSTARScore',
#        'Electricity(kBtu)', 'Electricity(kWh)', 'GHGEmissions(MetricTonsCO2e)',
#        'GHGEmissionsIntensity(kgCO2e/ft2)', 'LargestPropertyUseTypeGFA',
#        'NaturalGas(kBtu)', 'NaturalGas(therms)', 'NumberofBuildings',
#        'NumberofFloors', 'OSEBuildingID', 'OtherFuelUse(kBtu)',
#        'PropertyGFABuilding(s)', 'PropertyGFAParking', 'PropertyGFATotal',
#        'SPD Beats',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'SecondLargestPropertyUseTypeGFA', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SteamUse(kBtu)',
#        'YearBuilt', 'Zip Codes'],
#       dtype='object')

# %%
df_2015_obj.columns
# Out:
# Index(['BuildingType', 'ComplianceStatus', 'DefaultData',
#        'LargestPropertyUseType', 'ListOfAllPropertyUseTypes', 'Location',
#        'Neighborhood', 'PrimaryPropertyType', 'PropertyName',
#        'SecondLargestPropertyUseType', 'TaxParcelIdentificationNumber'],
#       dtype='object')

# %%
print(df_2015_num.isnull().values.sum())
# Out:
# 2

# %%
df_2015["NumberofBuildings"].fillna(df_2015["NumberofBuildings"].mean(), inplace = True)

# %%
df_2015_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 29 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   CouncilDistrictCode                                            3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   ENERGYSTARScore                                                3340 non-null   float64
#  3   Electricity(kBtu)                                              3340 non-null   float64
#  4   Electricity(kWh)                                               3340 non-null   float64
#  5   GHGEmissions(MetricTonsCO2e)                                   3340 non-null   float64
#  6   GHGEmissionsIntensity(kgCO2e/ft2)                              3340 non-null   float64
# ...

# %%
df_2015_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   BuildingType                   3340 non-null   object
#  1   ComplianceStatus               3340 non-null   object
#  2   DefaultData                    3339 non-null   object
#  3   LargestPropertyUseType         3204 non-null   object
#  4   ListOfAllPropertyUseTypes      3213 non-null   object
#  5   Location                       3340 non-null   object
#  6   Neighborhood                   3340 non-null   object
#  7   PrimaryPropertyType            3340 non-null   object
#  8   PropertyName                   3340 non-null   object
#  9   SecondLargestPropertyUseType   1560 non-null   object
#  10  TaxParcelIdentificationNumber  3338 non-null   object
# dtypes: object(11)
# memory usage: 287.2+ KB

# %%
#y=df_2015.BuildingType 

y = df_2015.BuildingType
BuildingType = y.value_counts()

# %%
BuildingType = y.value_counts()

# %%
y=df_2015.BuildingType

# %%
BuildingType
# Out:
# NonResidential          1461
# Multifamily LR (1-4)    1029
# Multifamily MR (5-9)     554
# Multifamily HR (10+)     107
# SPS-District K-12         99
# Nonresidential COS        68
# Campus                    22
# Name: BuildingType, dtype: int64

# %%
y
# Out:
# 0       NonResidential
# 1       NonResidential
# 2       NonResidential
# 3       NonResidential
# 4       NonResidential
#              ...
# 3313    NonResidential
# 3314    NonResidential
# 3319    NonResidential
# 3322    NonResidential
# 3334    NonResidential
# Name: BuildingType, Length: 1461, dtype: object

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(x,label="Count")       
#BuildingType =x.value_counts()
# Add labels
plt.title('BuildingType count')
plt.xlabel('BuildingType')
plt.ylabel('Count')
##NonResidential buildings are higher in number
# Out:
# Text(0, 0.5, 'Count')

# %%
#dataset where building type is NonResidential
df=df_2015[(df_2015['BuildingType'] =='NonResidential')]

# %%
df.describe()
# Out:
#        CouncilDistrictCode  DataYear  ENERGYSTARScore  Electricity(kBtu)  \
# count          1461.000000    1461.0      1461.000000       1.461000e+03
# mean              4.436003    2015.0        64.132495       5.448094e+06
# std               2.198889       0.0        24.342406       1.332909e+07
# min               1.000000    2015.0         1.000000       0.000000e+00
# 25%               2.000000    2015.0        57.000000       6.932260e+05
# 50%               4.000000    2015.0        67.894141       1.643962e+06
# 75%               7.000000    2015.0        80.000000       5.071562e+06
# max               7.000000    2015.0       100.000000       2.847263e+08
#
#        Electricity(kWh)  GHGEmissions(MetricTonsCO2e)  \
# count      1.461000e+03                   1461.000000
# mean       1.596679e+06                    163.152159
# std        3.906370e+06                    568.695798
# min        0.000000e+00                      0.000000
# ...

# %%
#seaborn Scatterplot
plt.figure(figsize=(15,6))
sns.scatterplot(x=df_2015['BuildingType'], y=df_2015['GHGEmissions(MetricTonsCO2e)'])
# GHGEmissions(MetricTonsCO2e) in Nonresidential building are more

# %%
#(z-score )normalization is applied on "GHGEmissionsIntensity(kgCO2e/ft2)"
plt.figure(figsize=(15,6))
df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"]-df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"].mean())/df_2015["GHGEmissionsIntensity(kgCO2e/ft2)"].std()
sns.boxplot(x='BuildingType',y="GHGEmissionsIntensity(kgCO2e/ft2)", data=df_2015)
#distribution of different categories of the “'BuildingType'” feature over GHGEmissionsIntensity(kgCO2e/ft2)"
#distribution of Campus as bulilding types(mean value) is different from other
# NonResidential uilding type has lot of outlier

# %%
#dataset where building type is NonResidential
#df=df_2015[(df_2015['BuildingType'] =='NonResidential')

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   3340 non-null   object
#  1   ComplianceStatus                                               3340 non-null   object
#  2   CouncilDistrictCode                                            3340 non-null   int64
#  3   DataYear                                                       3340 non-null   int64
#  4   DefaultData                                                    3339 non-null   object
#  5   ENERGYSTARScore                                                3340 non-null   float64
#  6   Electricity(kBtu)                                              3340 non-null   float64
# ...

# %%
#correlation map
#x=df
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df_2015.corr(), annot=True, linewidths=.7, fmt= '.1f',ax=ax)

# %%
#Pearson correlation matrix shows ,How each column are related to each other”
#Light colorscale 0.8 is highly correlated, and darker color below or around -0.2 is not correlated.
# helps in feature selection also

# %%
drop_list=["DataYear","Electricity(kWh)","NaturalGas(therms)","PropertyGFATotal","Seattle Police Department Micro Community Policing Plan Areas",
           "SiteEUI(kBtu/sf)","SiteEnergyUse(kBtu)","SourceEUI(kBtu/sf)","SiteEUI(kBtu/sf)","LargestPropertyUseTypeGFA","PropertyGFAParking","SiteEUIWN(kBtu/sf)"]

# %%
df_2015_x=df_2015.drop(drop_list,axis=1)

# %%
f,ax = plt.subplots(figsize=(18, 15))
sns.heatmap(df_2015_x.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
#drop_list_2=["LargestPropertyUseTypeGFA","PropertyGFAParking","SiteEUIWN(kBtu/sf)"]

# %%
#droped again "SiteEUI(kBtu/sf)","SiteEUIWN(kBtu/sf)".,"NumberofBuildings","PropertyGFAParking"from drop list
#

# %%
df_2015_x.head()
# Out:
#      BuildingType ComplianceStatus  CouncilDistrictCode DefaultData  \
# 0  NonResidential        Compliant                    7          No
# 1  NonResidential        Compliant                    7          No
# 2  NonResidential        Compliant                    7         Yes
# 3  NonResidential        Compliant                    7          No
# 4  NonResidential        Compliant                    7          No
#
#    ENERGYSTARScore  Electricity(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 0             65.0          3686160.0                        249.43
# 1             51.0          3905411.0                        263.51
# 2             18.0         49762435.0                       2061.48
# 3              1.0          2769023.0                       1936.34
# 4             67.0          6066245.0                        507.70
#
#    GHGEmissionsIntensity(kgCO2e/ft2) LargestPropertyUseType  \
# 0                           1.012199                  Hotel
# ...

# %%
df_2015_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   BuildingType                       3340 non-null   object
#  1   ComplianceStatus                   3340 non-null   object
#  2   CouncilDistrictCode                3340 non-null   int64
#  3   DefaultData                        3339 non-null   object
#  4   ENERGYSTARScore                    3340 non-null   float64
#  5   Electricity(kBtu)                  3340 non-null   float64
#  6   GHGEmissions(MetricTonsCO2e)       3340 non-null   float64
#  7   GHGEmissionsIntensity(kgCO2e/ft2)  3340 non-null   float64
#  8   LargestPropertyUseType             3204 non-null   object
#  9   ListOfAllPropertyUseTypes          3213 non-null   object
#  10  Location                           3340 non-null   object
# ...

# %%
##To select  numeric types and object types
df_2015_x_num=df_2015_x.select_dtypes(np.number)
df_2015_x_obj=df_2015_x.select_dtypes('object')

# %%
df_2015_x_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CouncilDistrictCode                3340 non-null   int64
#  1   ENERGYSTARScore                    3340 non-null   float64
#  2   Electricity(kBtu)                  3340 non-null   float64
#  3   GHGEmissions(MetricTonsCO2e)       3340 non-null   float64
#  4   GHGEmissionsIntensity(kgCO2e/ft2)  3340 non-null   float64
#  5   NaturalGas(kBtu)                   3340 non-null   float64
#  6   NumberofBuildings                  3340 non-null   int64
#  7   NumberofFloors                     3340 non-null   float64
#  8   OSEBuildingID                      3340 non-null   int64
#  9   OtherFuelUse(kBtu)                 3340 non-null   float64
#  10  PropertyGFABuilding(s)             3340 non-null   int64
# ...

# %%
y=df_2015.BuildingType

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

# split data train 70 % and test 30 %
#y=df_2015.BuildingType
x_train, x_test, y_train, y_test = train_test_split(df_2015_x_num, y, test_size=0.3, random_state=42)
clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy is:  0.8702594810379242
