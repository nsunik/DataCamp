# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns
df_2015=pd.read_csv(r'C:\Users\DELL\Downloads\2015-building-energy-benchmarking.csv')
df_2016=pd.read_csv(r'C:\Users\DELL\Downloads\2016-building-energy-benchmarking.csv')

# %%
#basic data analysis
df_2015.head() #showes first five rows of the data set
# 47 columns
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# ...

# %%
#basic data analysis
df_2016.head() #showes first five rows of the data set
#46 columns
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  ...  Electricity(kWh) Electricity(kBtu)  \
# 0                    0659000030  ...      1.156514e+06         3946027.0
# ...

# %%
col = df_2015.columns       # .columns gives columns names in data 
print(col)
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
col = df_2016.columns       # .columns gives columns names in data 
print(col)
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
# ...

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
#drop the columns which has lot of missing values
df_2015.drop(['Comment' ,'Outlier','2010 Census Tracts','City Council Districts','ThirdLargestPropertyUseTypeGFA','ThirdLargestPropertyUseType','YearsENERGYSTARCertified'],axis=1, inplace=True)

# %%
df_2015.info()
#40 columns
#7cols droped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 40 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
# ...

# %%
df_2016.drop(['Comments','Outlier','YearsENERGYSTARCertified','ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA'] ,axis=1,inplace=True)

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    3376 non-null   int64
#  1   DataYear                         3376 non-null   int64
#  2   BuildingType                     3376 non-null   object
#  3   PrimaryPropertyType              3376 non-null   object
#  4   PropertyName                     3376 non-null   object
#  5   Address                          3376 non-null   object
#  6   City                             3376 non-null   object
#  7   State                            3376 non-null   object
#  8   ZipCode                          3360 non-null   float64
#  9   TaxParcelIdentificationNumber    3376 non-null   object
#  10  CouncilDistrictCode              3376 non-null   int64
#  11  Neighborhood                     3376 non-null   object
# ...

# %%
set(df_2016)-set(df_2015)
# Out:
# {'Address',
#  'City',
#  'GHGEmissionsIntensity',
#  'Latitude',
#  'Longitude',
#  'State',
#  'TotalGHGEmissions',
#  'ZipCode'}

# %%
df_2015.rename(columns={'Zip Codes':'ZipCode','GHGEmissions(MetricTonsCO2e)':'TotalGHGEmissions','GHGEmissionsIntensity(kgCO2e/ft2)':'GHGEmissionsIntensity'}, inplace=True )
#Rename df_2015 data columns as 2016 data columns,

# %%
set(df_2016)-set(df_2015)
#5 cols {'Address', 'City', 'Latitude', 'Longitude', 'State'}
# Out:
# {'Address', 'City', 'Latitude', 'Longitude', 'State'}

# %%
#sort the column
df_2015=df_2015.reindex(sorted(df_2015.columns), axis=1)
df_2016=df_2016.reindex(sorted(df_2016.columns), axis=1)

# %%
print(len(df_2016.columns),len(df_2015.columns))
#41 40
# Out:
# 41 40

# %%
df=pd.concat([df_2015,df_2016],ignore_index=True)

# %%
#df=Combine data from(df_2015,df_2016) data set 
df=pd.concat([df_2015,df_2016],ignore_index=True)
df.drop_duplicates(inplace=True)

# %%
df.info()
#total 45 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 45 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   6716 non-null   object
#  1   ComplianceStatus                                               6716 non-null   object
#  2   CouncilDistrictCode                                            6716 non-null   int64
#  3   DataYear                                                       6716 non-null   int64
#  4   DefaultData                                                    6715 non-null   object
#  5   ENERGYSTARScore                                                5093 non-null   float64
#  6   Electricity(kBtu)                                              6697 non-null   float64
# ...

# %%
#describe the "ENERGYSTARScore" -basic statistical details
df["ENERGYSTARScore"].describe()
# Out:
# count    5093.000000
# mean       67.906342
# std        27.012124
# min         1.000000
# 25%        52.000000
# 50%        75.000000
# 75%        90.000000
# max       100.000000
# Name: ENERGYSTARScore, dtype: float64

# %%
#fill the missing value of ["ENERGYSTARScore"] with mean
df["ENERGYSTARScore"].fillna( df_2015["ENERGYSTARScore"].mean(), inplace = True)

# %%
df["Electricity(kBtu)"].fillna(df["Electricity(kBtu)"].mean(),inplace=True)
#df_2016["ENERGYSTARScore"].fillna(df_2016["ENERGYSTARScore"].mean() ,inplace=True)

# %%
df["Electricity(kWh)"].fillna( df["Electricity(kWh)"].mean(), inplace = True)

# %%
df["GHGEmissionsIntensity"].fillna( df["GHGEmissionsIntensity"].mean(), inplace = True)

# %%
df["LargestPropertyUseType"].fillna( df["LargestPropertyUseType"].mode(), inplace = True)

# %%
df["LargestPropertyUseTypeGFA"].fillna( df["LargestPropertyUseTypeGFA"].mean(), inplace = True)

# %%
df["ListOfAllPropertyUseTypes"].fillna( df["ListOfAllPropertyUseTypes"].mode(), inplace = True)

# %%
df["Location"].fillna( df["Location"].mode(), inplace = True)

# %%
df["NaturalGas(kBtu)"].fillna( df["NaturalGas(kBtu)"].mean(), inplace = True)

# %%
df["NaturalGas(therms)"].fillna( df["NaturalGas(therms)"].mean(), inplace = True)

# %%
df["NumberofBuildings"].fillna( df["NumberofBuildings"].mean(), inplace = True)

# %%
df["OtherFuelUse(kBtu)"].fillna( df["OtherFuelUse(kBtu)"].mean(), inplace = True)

# %%
#df["PrimaryPropertyType"].fillna( df["PrimaryPropertyType"].mode(), inplace = True)

# %%
df["PropertyGFABuilding(s)"].fillna( df["PropertyGFABuilding(s)"].mean(), inplace = True)

# %%
df["SPD Beats"].fillna( df["SPD Beats"].mode(), inplace = True)

# %%
#Seattle Police Department Micro Community Policing Plan Areas
#Seattle Police Department Micro Community Policing Plan Areas
df["Seattle Police Department Micro Community Policing Plan Areas"].fillna( df["Seattle Police Department Micro Community Policing Plan Areas"].mode(), inplace = True)

# %%
df["SecondLargestPropertyUseType"].fillna( df["SecondLargestPropertyUseType"].mode(), inplace = True)

# %%
df["SecondLargestPropertyUseTypeGFA"].fillna( df["SecondLargestPropertyUseTypeGFA"].mean(), inplace = True)

# %%
df["SiteEUI(kBtu/sf)"].fillna( df["SiteEUI(kBtu/sf)"].mean(), inplace = True)

# %%
df["SiteEUIWN(kBtu/sf)"].fillna( df["SiteEUIWN(kBtu/sf)"].mean(), inplace = True)

# %%
df["SteamUse(kBtu)"].fillna( df["SteamUse(kBtu)"].mean(), inplace = True)

# %%
df["TaxParcelIdentificationNumber"].fillna( df["TaxParcelIdentificationNumber"].mode(), inplace = True)

# %%
df["TotalGHGEmissions"].fillna( df["TotalGHGEmissions"].mean(), inplace = True)

# %%
df["ZipCode"].fillna( df["ZipCode"].mode(), inplace = True)

# %%
df["Address"].fillna( df["Address"].mode(), inplace = True)

# %%
df["City"].fillna( df["City"].mode(), inplace = True)

# %%
df["Latitude"].fillna( df["Latitude"].mode(), inplace = True)

# %%
df["Longitude"].fillna( df["Longitude"].mode(), inplace = True)

# %%
df["State"].fillna( df["State"].mode(), inplace = True)

# %%
df["DefaultData"].fillna( df["DefaultData"].mode(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 45 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   6716 non-null   object
#  1   ComplianceStatus                                               6716 non-null   object
#  2   CouncilDistrictCode                                            6716 non-null   int64
#  3   DataYear                                                       6716 non-null   int64
#  4   DefaultData                                                    6715 non-null   object
#  5   ENERGYSTARScore                                                6716 non-null   float64
#  6   Electricity(kBtu)                                              6716 non-null   float64
# ...

# %%
df.describe()
# 31  31 columns
# Out:
#        CouncilDistrictCode    DataYear  ENERGYSTARScore  Electricity(kBtu)  \
# count          6716.000000  6716.00000      6716.000000       6.716000e+03
# mean              4.445057  2015.50268        67.903393       3.591058e+06
# std               2.123749     0.50003        23.522308       1.246960e+07
# min               1.000000  2015.00000         1.000000      -1.154170e+05
# 25%               3.000000  2015.00000        61.000000       6.382205e+05
# 50%               4.000000  2016.00000        67.894141       1.170658e+06
# 75%               7.000000  2016.00000        86.000000       2.811583e+06
# max               7.000000  2016.00000       100.000000       6.570744e+08
#
#        Electricity(kWh)  GHGEmissionsIntensity  LargestPropertyUseTypeGFA  \
# count      6.716000e+03            6716.000000               6.716000e+03
# mean       1.052458e+06               1.081154               7.707936e+04
# ...

# %%
#To select  numeric types and object types

df_num=df.select_dtypes(np.number)
df_obj=df.select_dtypes('object')

# %%
df_num.columns
# Out:
# Index(['CouncilDistrictCode', 'DataYear', 'ENERGYSTARScore',
#        'Electricity(kBtu)', 'Electricity(kWh)', 'GHGEmissionsIntensity',
#        'LargestPropertyUseTypeGFA', 'NaturalGas(kBtu)', 'NaturalGas(therms)',
#        'NumberofBuildings', 'NumberofFloors', 'OSEBuildingID',
#        'OtherFuelUse(kBtu)', 'PropertyGFABuilding(s)', 'PropertyGFAParking',
#        'PropertyGFATotal', 'SPD Beats',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'SecondLargestPropertyUseTypeGFA', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SteamUse(kBtu)',
#        'TotalGHGEmissions', 'YearBuilt', 'ZipCode', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_num.info()
#31 total 31 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 31 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   CouncilDistrictCode                                            6716 non-null   int64
#  1   DataYear                                                       6716 non-null   int64
#  2   ENERGYSTARScore                                                6716 non-null   float64
#  3   Electricity(kBtu)                                              6716 non-null   float64
#  4   Electricity(kWh)                                               6716 non-null   float64
#  5   GHGEmissionsIntensity                                          6716 non-null   float64
#  6   LargestPropertyUseTypeGFA                                      6716 non-null   float64
# ...

# %%
df_nor_1=(df_num-df_num.mean())/(df_num.std()) 
#nomalized data(normalization)(df_num)
#data_n_2 = (data - data.mean()) / (data.std())

# %%
df.BuildingType
# Out:
# 0           NonResidential
# 1           NonResidential
# 2           NonResidential
# 3           NonResidential
# 4           NonResidential
#                ...
# 6711    Nonresidential COS
# 6712    Nonresidential COS
# 6713    Nonresidential COS
# 6714    Nonresidential COS
# 6715    Nonresidential COS
# Name: BuildingType, Length: 6716, dtype: object

# %%
y = df.BuildingType
BuildingType = y.value_counts()

# %%
y = df.BuildingType

# %%
BuildingType = y.value_counts()

# %%
BuildingType
# Out:
# NonResidential          2921
# Multifamily LR (1-4)    2047
# Multifamily MR (5-9)    1134
# Multifamily HR (10+)     217
# SPS-District K-12        197
# Nonresidential COS       153
# Campus                    46
# Nonresidential WA          1
# Name: BuildingType, dtype: int64

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(y,label="Count")       
BuildingType = y.value_counts()
#NonResidential buildingtype is larger

# %%
#(z-score )normalization is applied on "TotalGHGEmissions"
plt.figure(figsize=(15,6))
df["TotalGHGEmissions"]=(df["TotalGHGEmissions"]-df["TotalGHGEmissions"].mean())/df["TotalGHGEmissions"].std()
sns.boxplot(x='BuildingType',y="TotalGHGEmissions", data=df)
#distribution of different categories of the “'BuildingType'” feature over TotalGHGEmissions"
#distribution of Campus as bulilding types(mean value) is different from other
# NonResidential uilding type has lot of outlier
# Multifamily MR (5-9),SPS-District K-12 , Multifamily LR (1-4), have almost same mean

# %%
#simple feature scaling(range 0-1)
#xnew=xold/xmax
plt.figure(figsize=(15,6))
df["GHGEmissionsIntensity"]=(df["GHGEmissionsIntensity"])/df["GHGEmissionsIntensity"].max()
sns.boxplot(x='BuildingType',y="GHGEmissionsIntensity", data=df)
#distribution of Multifamily MR (5-9) and Multifamily LR (1-4) are same 
#SPS-District K-12 and Multifamily HR (10+)  have almost same distribution

# %%
#jointplot
#positive relationship between the columns
#because if the values of one variable increase so does the other
sns.jointplot(x='SiteEUI(kBtu/sf)', y='SourceEUI(kBtu/sf)',kind="regg" ,data=df, color="#ce1414")
plt.show()

# %%
sns.jointplot(x='SiteEnergyUse(kBtu)', y='SourceEUI(kBtu/sf)',kind="regg" ,data=df, color="#ce1414")
plt.show()
#no correlation

# %%
sns.jointplot(x='Electricity(kBtu)', y='Electricity(kWh)',kind="regg" ,data=df, color="#ce1414")
plt.show()

# %%
df_NonResidential=df[(df['BuildingType'] =='NonResidential')]

# %%
df_NonResidential.head()
45 columns
# Out:
#      BuildingType ComplianceStatus  CouncilDistrictCode  DataYear DefaultData  \
# 0  NonResidential        Compliant                    7      2015          No
# 1  NonResidential        Compliant                    7      2015          No
# 2  NonResidential        Compliant                    7      2015         Yes
# 3  NonResidential        Compliant                    7      2015          No
# 4  NonResidential        Compliant                    7      2015          No
#
#    ENERGYSTARScore  Electricity(kBtu)  Electricity(kWh)  \
# 0             65.0          3686160.0         1080307.0
# 1             51.0          3905411.0         1144563.0
# 2             18.0         49762435.0        14583930.0
# 3              1.0          2769023.0          811521.0
# 4             67.0          6066245.0         1777841.0
#
#    GHGEmissionsIntensity LargestPropertyUseType  ...  SteamUse(kBtu)  \
# 0                   2.64                  Hotel  ...       2023032.0
# ...

# %%
df_NonResidential.info()
#2921 entries  45 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2921 entries, 0 to 6696
# Data columns (total 45 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   BuildingType                                                   2921 non-null   object
#  1   ComplianceStatus                                               2921 non-null   object
#  2   CouncilDistrictCode                                            2921 non-null   int64
#  3   DataYear                                                       2921 non-null   int64
#  4   DefaultData                                                    2920 non-null   object
#  5   ENERGYSTARScore                                                2921 non-null   float64
#  6   Electricity(kBtu)                                              2921 non-null   float64
# ...

# %%
#heatmap(correlation matrix)
#observe all correlation between features
f,ax = plt.subplots(figsize=(18, 15))
sns.heatmap(df.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
drop_list=["Electricity(kWh)","NaturalGas(therms)","LargestPropertyUseTypeGFA","PropertyGFABuilding(s)","SiteEUIWN(kBtu/sf)",
           "SourceEUIWN(kBtu/sf)","SiteEUI(kBtu/sf)","SiteEnergyUseWN(kBtu)","ZipCode","SPD Beats","Seattle Police Department Micro Community Policing Plan Areas",
           "SiteEnergyUse(kBtu)","Latitude","Longitude","NumberofFloors","PropertyGFAParking"]
df_1=df.drop(drop_list,axis=1)

# %%
f,ax = plt.subplots(figsize=(18, 15))
sns.heatmap(df_1.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
df_1.head()
# Out:
#      BuildingType ComplianceStatus  CouncilDistrictCode  DataYear DefaultData  \
# 0  NonResidential        Compliant                    7      2015          No
# 1  NonResidential        Compliant                    7      2015          No
# 2  NonResidential        Compliant                    7      2015         Yes
# 3  NonResidential        Compliant                    7      2015          No
# 4  NonResidential        Compliant                    7      2015          No
#
#    ENERGYSTARScore  Electricity(kBtu)  GHGEmissionsIntensity  \
# 0             65.0          3686160.0                   2.64
# 1             51.0          3905411.0                   2.38
# 2             18.0         49762435.0                   1.92
# 3              1.0          2769023.0                  31.38
# 4             67.0          6066245.0                   4.02
#
#   LargestPropertyUseType      ListOfAllPropertyUseTypes  ...  \
# 0                  Hotel                          Hotel  ...
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   BuildingType                     6716 non-null   object
#  1   ComplianceStatus                 6716 non-null   object
#  2   CouncilDistrictCode              6716 non-null   int64
#  3   DataYear                         6716 non-null   int64
#  4   DefaultData                      6715 non-null   object
#  5   ENERGYSTARScore                  6716 non-null   float64
#  6   Electricity(kBtu)                6716 non-null   float64
#  7   GHGEmissionsIntensity            6716 non-null   float64
#  8   LargestPropertyUseType           6560 non-null   object
#  9   ListOfAllPropertyUseTypes        6580 non-null   object
#  10  Location                         3340 non-null   object
#  11  NaturalGas(kBtu)                 6716 non-null   float64
# ...

# %%
df_1_num=df_1.select_dtypes(np.number)
#select numerical values from df-1

# %%
#df_1_num normalize the data
df_1_num_nor=(df_1_num-df_1_num.mean())/(df_1_num.std())

# %%
df_1_num_nor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CouncilDistrictCode              6716 non-null   float64
#  1   DataYear                         6716 non-null   float64
#  2   ENERGYSTARScore                  6716 non-null   float64
#  3   Electricity(kBtu)                6716 non-null   float64
#  4   GHGEmissionsIntensity            6716 non-null   float64
#  5   NaturalGas(kBtu)                 6716 non-null   float64
#  6   NumberofBuildings                6716 non-null   float64
#  7   OSEBuildingID                    6716 non-null   float64
#  8   OtherFuelUse(kBtu)               6716 non-null   float64
#  9   PropertyGFATotal                 6716 non-null   float64
#  10  SecondLargestPropertyUseTypeGFA  6716 non-null   float64
# ...

# %%
#data_n_2 = (data - data.mean()) / (data.std())
df["SourceEUI(kBtu/sf)"]=df["SourceEUI(kBtu/sf)"]-df["SourceEUI(kBtu/sf)"].mean()/df["SourceEUI(kBtu/sf)"].std()
df["SourceEUI(kBtu/sf)"].fillna( df["SourceEUI(kBtu/sf)"].mean(), inplace = True)

# %%
df["SourceEUI(kBtu/sf)"].describe()
# Out:
# count    6716.000000
# mean      133.510303
# std       135.485111
# min        -2.000000
# 25%        74.099998
# 50%        95.800003
# 75%       143.800003
# max      2620.000000
# Name: SourceEUI(kBtu/sf), dtype: float64

# %%
df["SourceEUI(kBtu/sf)"]=(df["SourceEUI(kBtu/sf)"])/df["SourceEUI(kBtu/sf)"].max()

# %%
df["SourceEUI(kBtu/sf)"].fillna( df["SourceEUI(kBtu/sf)"].mean(), inplace = True)

# %%
df_1_num_nor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CouncilDistrictCode              6716 non-null   float64
#  1   DataYear                         6716 non-null   float64
#  2   ENERGYSTARScore                  6716 non-null   float64
#  3   Electricity(kBtu)                6716 non-null   float64
#  4   GHGEmissionsIntensity            6716 non-null   float64
#  5   NaturalGas(kBtu)                 6716 non-null   float64
#  6   NumberofBuildings                6716 non-null   float64
#  7   OSEBuildingID                    6716 non-null   float64
#  8   OtherFuelUse(kBtu)               6716 non-null   float64
#  9   PropertyGFATotal                 6716 non-null   float64
#  10  SecondLargestPropertyUseTypeGFA  6716 non-null   float64
# ...

# %%
df_1_num_nor=df_1_num_nor.drop("SourceEUI(kBtu/sf)",axis=1)

# %%
df_1_num_nor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6716 entries, 0 to 6715
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CouncilDistrictCode              6716 non-null   float64
#  1   DataYear                         6716 non-null   float64
#  2   ENERGYSTARScore                  6716 non-null   float64
#  3   Electricity(kBtu)                6716 non-null   float64
#  4   GHGEmissionsIntensity            6716 non-null   float64
#  5   NaturalGas(kBtu)                 6716 non-null   float64
#  6   NumberofBuildings                6716 non-null   float64
#  7   OSEBuildingID                    6716 non-null   float64
#  8   OtherFuelUse(kBtu)               6716 non-null   float64
#  9   PropertyGFATotal                 6716 non-null   float64
#  10  SecondLargestPropertyUseTypeGFA  6716 non-null   float64
# ...

# %%
#df["SourceEUI(kBtu/sf)"]=df["SourceEUI(kBtu/sf)"]-df["SourceEUI(kBtu/sf)"].mean()/df["SourceEUI(kBtu/sf)"].std()
#df["SourceEUI(kBtu/sf)"].fillna( df["SourceEUI(kBtu/sf)"].mean(), inplace = True)

# %%
#import pandas as pd
#from sklearn import datasets, linear_model
#from sklearn.model_selection import train_test_split
#from matplotlib import pyplot as plt

# %%
#X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
#print (x_train.shape, y_train.shape)
#print (x_test.shape, y_test.shape)
#(353, 10) (353,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-e5e0b18c78ec> in <module>
#       1 X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)
# ----> 2 print (x_train.shape, y_train.shape)
#       3 print (x_test.shape, y_test.shape)
#       4 #(353, 10) (353,)
#
# NameError: name 'x_train' is not defined

# %%
##nomalized data(normalization)(df_num)
#data_n_2 = (data - data.mean()) / (data.std())
#df_1_num_nor=(df_1_num-df_1_num.mean())/(df_1_num.std())         #normalize the numerical values from df-1
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

# split data train 70 % and test 30 %
x_train, x_test, y_train, y_test = train_test_split(df_1_num_nor, y, test_size=0.3, random_state=42)
clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy is:  0.824317617866005

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score
# split data train 70 % and test 30 %
#y=df.BuildingType
#float = float(df.BuildingType)
df["BuildingType"]=df["BuildingType"].astype(float)
y=df["BuildingType"]
x_train, x_test, y_train, y_test = train_test_split(df_1, y, test_size=0.3, random_state=42)

#random forest classifier with n_estimators=10 (default)
clf_rf = RandomForestClassifier(random_state=42)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")

# %%
df_1.head()
#29 cols
# Out:
#      BuildingType ComplianceStatus  CouncilDistrictCode  DataYear DefaultData  \
# 0  NonResidential        Compliant                    7      2015          No
# 1  NonResidential        Compliant                    7      2015          No
# 2  NonResidential        Compliant                    7      2015         Yes
# 3  NonResidential        Compliant                    7      2015          No
# 4  NonResidential        Compliant                    7      2015          No
#
#    ENERGYSTARScore  Electricity(kBtu)  GHGEmissionsIntensity  \
# 0             65.0          3686160.0               0.077442
# 1             51.0          3905411.0               0.069815
# 2             18.0         49762435.0               0.056322
# 3              1.0          2769023.0               0.920505
# 4             67.0          6066245.0               0.117923
#
#   LargestPropertyUseType      ListOfAllPropertyUseTypes  ...  \
# 0                  Hotel                          Hotel  ...
# ...

# %%
#one hot code for building type
pd.get_dummies(df['BuildingType'])
# Out:
#       Campus  Multifamily HR (10+)  Multifamily LR (1-4)  \
# 0          0                     0                     0
# 1          0                     0                     0
# 2          0                     0                     0
# 3          0                     0                     0
# 4          0                     0                     0
# ...      ...                   ...                   ...
# 6711       0                     0                     0
# 6712       0                     0                     0
# 6713       0                     0                     0
# 6714       0                     0                     0
# 6715       0                     0                     0
#
#       Multifamily MR (5-9)  NonResidential  Nonresidential COS  \
# 0                        0               1                   0
# 1                        0               1                   0
# 2                        0               1                   0
# ...

# %%
y=pd.get_dummies(df['BuildingType'])

# %%
y
# Out:
#       Campus  Multifamily HR (10+)  Multifamily LR (1-4)  \
# 0          0                     0                     0
# 1          0                     0                     0
# 2          0                     0                     0
# 3          0                     0                     0
# 4          0                     0                     0
# ...      ...                   ...                   ...
# 6711       0                     0                     0
# 6712       0                     0                     0
# 6713       0                     0                     0
# 6714       0                     0                     0
# 6715       0                     0                     0
#
#       Multifamily MR (5-9)  NonResidential  Nonresidential COS  \
# 0                        0               1                   0
# 1                        0               1                   0
# 2                        0               1                   0
# ...

# %%
df_BuildingType
# Out:
# NonResidential          2921
# Multifamily LR (1-4)    2047
# Multifamily MR (5-9)    1134
# Multifamily HR (10+)     217
# SPS-District K-12        197
# Nonresidential COS       153
# Campus                    46
# Nonresidential WA          1
# Name: BuildingType, dtype: int64

# %%
y=df['BuildingType']

# %%
y
# Out:
# 0           NonResidential
# 1           NonResidential
# 2           NonResidential
# 3           NonResidential
# 4           NonResidential
#                ...
# 6711    Nonresidential COS
# 6712    Nonresidential COS
# 6713    Nonresidential COS
# 6714    Nonresidential COS
# 6715    Nonresidential COS
# Name: BuildingType, Length: 6716, dtype: object

# %%
df["BuildingType"]
# Out:
# 0           NonResidential
# 1           NonResidential
# 2           NonResidential
# 3           NonResidential
# 4           NonResidential
#                ...
# 6711    Nonresidential COS
# 6712    Nonresidential COS
# 6713    Nonresidential COS
# 6714    Nonresidential COS
# 6715    Nonresidential COS
# Name: BuildingType, Length: 6716, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score
# split data train 70 % and test 30 %
#y=df.BuildingType
#float = float(df.BuildingType)
df["BuildingType"]=df["BuildingType"].astype(float)
y=df["BuildingType"]
x_train, x_test, y_train, y_test = train_test_split(df_1, y, test_size=0.3, random_state=42)

#random forest classifier with n_estimators=10 (default)
clf_rf = RandomForestClassifier(random_state=42)      
clr_rf = clf_rf.fit(x_train,y_train)

ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-b0bda7d92bbc> in <module>
#       6 #y=df.BuildingType
#       7 #float = float(df.BuildingType)
# ----> 8 df["BuildingType"]=df["BuildingType"].astype(float)
#       9 y=df["BuildingType"]
#      10 x_train, x_test, y_train, y_test = train_test_split(df_1, y, test_size=0.3, random_state=42)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored 5 features
select_feature = SelectKBest(chi2, k=10).fit(x_train, y_train)
print('Score list:', select_feature.scores_)
print('Feature list:', x_train.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-181-8ebc999ab28e> in <module>
#       2 from sklearn.feature_selection import chi2
#       3 # find best scored 5 features
# ----> 4 select_feature = SelectKBest(chi2, k=10).fit(x_train, y_train)
#       5 print('Score list:', select_feature.scores_)
#       6 print('Feature list:', x_train.columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     342         self : object
#     343         """
# --> 344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
#     345                                    multi_output=True)
#     346
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
# ...

# %%
#Recursive feature elimination (RFE) with random forest
from sklearn.feature_selection import RFE
clf_rf_3 = RandomForestClassifier()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=10, step=1)
rfe = rfe.fit(x_train, y_train)
print('Chosen best 10 feature by rfe:',x_train.columns[rfe.support_])
#chosen best 10 feature by rfe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-730cb6636251> in <module>
#       3 clf_rf_3 = RandomForestClassifier()
#       4 rfe = RFE(estimator=clf_rf_3, n_features_to_select=10, step=1)
# ----> 5 rfe = rfe.fit(x_train, y_train)
#       6 print('Chosen best 10 feature by rfe:',x_train.columns[rfe.support_])
#       7 #chosen best 10 feature by rfe
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py in fit(self, X, y)
#     149             The target values.
#     150         """
# --> 151         return self._fit(X, y)
#     152
#     153     def _fit(self, X, y, step_score=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py in _fit(self, X, y, step_score)
#     158
#     159         tags = self._get_tags()
# --> 160         X, y = self._validate_data(
# ...
