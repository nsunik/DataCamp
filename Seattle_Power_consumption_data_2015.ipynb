# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
df=pd.read_csv(r'C:\Users\DELL\Downloads\2015-building-energy-benchmarking.csv')
#predict the emissions of buildings whose emissions have not yet been measured.

# %%
#basic data analysis,quick view of data set
#showes first five rows of the data se
df.head()
#47 columns
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# 2  {'latitude': '47.61334897', 'longitude': '-122...                    7
# 3  {'latitude': '47.61421585', 'longitude': '-122...                    7
# 4  {'latitude': '47.6137544', 'longitude': '-122....                    7
#
#   Neighborhood  YearBuilt  ...  GHGEmissionsIntensity(kgCO2e/ft2)  \
# 0     DOWNTOWN       1927  ...                               2.64
# 1     DOWNTOWN       1996  ...                               2.38
# 2     DOWNTOWN       1969  ...                               1.92
# 3     DOWNTOWN       1926  ...                              31.38
# 4     DOWNTOWN       1980  ...                               4.02
#
#    DefaultData  Comment  ComplianceStatus       Outlier 2010 Census Tracts  \
# 0           No      NaN         Compliant           NaN                NaN
# 1           No      NaN         Compliant           NaN                NaN
# 2          Yes      NaN         Compliant           NaN                NaN
# 3           No      NaN         Compliant  High Outlier                NaN
# 4           No      NaN         Compliant           NaN                NaN
#
#   Seattle Police Department Micro Community Policing Plan Areas  \
# 0                                               14.0
# 1                                               14.0
# 2                                               56.0
# 3                                               56.0
# 4                                               56.0
#
#    City Council Districts SPD Beats  Zip Codes
# 0                     NaN      31.0      18081
# 1                     NaN      31.0      18081
# 2                     NaN      31.0      18081
# 3                     NaN      31.0      18081
# 4                     NaN      31.0      19576
#
# [5 rows x 47 columns]

# %%
#summary statistics
df.describe()
# Out:
#        OSEBuildingID  DataYear  CouncilDistrictCode    YearBuilt  \
# count    3340.000000    3340.0          3340.000000  3340.000000
# mean    20522.168263    2015.0             4.450898  1967.624850
# std     11511.515874       0.0             2.127203    32.949847
# min         1.000000    2015.0             1.000000  1900.000000
# 25%     19921.750000    2015.0             3.000000  1947.000000
# 50%     22977.000000    2015.0             4.000000  1973.000000
# 75%     25748.000000    2015.0             7.000000  1996.000000
# max     50059.000000    2015.0             7.000000  2015.000000
#
#        NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# count        3340.000000     3332.000000      3.340000e+03
# mean            1.035629        4.682173      9.077289e+04
# std             0.784463        5.458460      1.493058e+05
# min             1.000000        0.000000      2.000000e+04
# 25%             1.000000        2.000000      2.848700e+04
# 50%             1.000000        4.000000      4.385500e+04
# 75%             1.000000        5.000000      8.842800e+04
# max            39.000000       99.000000      2.200000e+06
#
#        PropertyGFAParking  PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# count         3340.000000            3.340000e+03               3.204000e+03
# mean         11054.032335            7.971886e+04               7.488154e+04
# std          35296.330507            1.292314e+05               1.236249e+05
# min             -3.000000           -5.055000e+04               5.872000e+03
# 25%              0.000000            2.668300e+04               2.500000e+04
# 50%              0.000000            4.132600e+04               3.900000e+04
# 75%           4304.250000            7.872600e+04               7.206750e+04
# max         512608.000000            2.200000e+06               1.719643e+06
#
#        ...  NaturalGas(therms)  NaturalGas(kBtu)  OtherFuelUse(kBtu)  \
# count  ...        3.330000e+03      3.330000e+03        3.330000e+03
# mean   ...        1.253304e+04      1.253304e+06        7.142301e+03
# std    ...        4.415142e+04      4.415142e+06        1.962790e+05
# min    ...        0.000000e+00      0.000000e+00        0.000000e+00
# 25%    ...        0.000000e+00      0.000000e+00        0.000000e+00
# 50%    ...        2.945500e+03      2.945770e+05        0.000000e+00
# 75%    ...        1.115325e+04      1.115366e+06        0.000000e+00
# max    ...        1.364484e+06      1.364484e+08        8.269669e+06
#
#        GHGEmissions(MetricTonsCO2e)  GHGEmissionsIntensity(kgCO2e/ft2)  \
# count                   3330.000000                        3330.000000
# mean                     110.094102                           0.985339
# std                      409.450179                           1.637172
# min                        0.000000                           0.000000
# 25%                        9.265000                           0.080000
# 50%                       32.740000                           0.460000
# 75%                       88.642500                           1.180000
# max                    11824.890000                          31.380000
#
#        2010 Census Tracts  \
# count          224.000000
# mean           123.062500
# std              5.812128
# min            116.000000
# 25%            117.000000
# 50%            123.000000
# 75%            125.500000
# max            135.000000
#
#        Seattle Police Department Micro Community Policing Plan Areas  \
# count                                        3338.000000
# mean                                           32.380168
# std                                            19.907567
# min                                             1.000000
# 25%                                            14.000000
# 50%                                            33.000000
# 75%                                            50.000000
# max                                            61.000000
#
#        City Council Districts    SPD Beats     Zip Codes
# count              213.000000  3338.000000   3340.000000
# mean                 1.347418    24.825644  18786.680240
# std                  0.477272    15.006287    588.604192
# min                  1.000000     1.000000  17916.000000
# 25%                  1.000000    10.000000  18379.000000
# 50%                  1.000000    26.000000  18390.000000
# 75%                  2.000000    38.000000  19576.000000
# max                  2.000000    51.000000  19584.000000
#
# [8 rows x 32 columns]

# %%
#nature of dataset columns (attributes).
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
#  7   CouncilDistrictCode                                            3340 non-null   int64
#  8   Neighborhood                                                   3340 non-null   object
#  9   YearBuilt                                                      3340 non-null   int64
#  10  NumberofBuildings                                              3340 non-null   int64
#  11  NumberofFloors                                                 3332 non-null   float64
#  12  PropertyGFATotal                                               3340 non-null   int64
#  13  PropertyGFAParking                                             3340 non-null   int64
#  14  PropertyGFABuilding(s)                                         3340 non-null   int64
#  15  ListOfAllPropertyUseTypes                                      3213 non-null   object
#  16  LargestPropertyUseType                                         3204 non-null   object
#  17  LargestPropertyUseTypeGFA                                      3204 non-null   float64
#  18  SecondLargestPropertyUseType                                   1559 non-null   object
#  19  SecondLargestPropertyUseTypeGFA                                1559 non-null   float64
#  20  ThirdLargestPropertyUseType                                    560 non-null    object
#  21  ThirdLargestPropertyUseTypeGFA                                 560 non-null    float64
#  22  YearsENERGYSTARCertified                                       110 non-null    object
#  23  ENERGYSTARScore                                                2560 non-null   float64
#  24  SiteEUI(kBtu/sf)                                               3330 non-null   float64
#  25  SiteEUIWN(kBtu/sf)                                             3330 non-null   float64
#  26  SourceEUI(kBtu/sf)                                             3330 non-null   float64
#  27  SourceEUIWN(kBtu/sf)                                           3330 non-null   float64
#  28  SiteEnergyUse(kBtu)                                            3330 non-null   float64
#  29  SiteEnergyUseWN(kBtu)                                          3330 non-null   float64
#  30  SteamUse(kBtu)                                                 3330 non-null   float64
#  31  Electricity(kWh)                                               3330 non-null   float64
#  32  Electricity(kBtu)                                              3330 non-null   float64
#  33  NaturalGas(therms)                                             3330 non-null   float64
#  34  NaturalGas(kBtu)                                               3330 non-null   float64
#  35  OtherFuelUse(kBtu)                                             3330 non-null   float64
#  36  GHGEmissions(MetricTonsCO2e)                                   3330 non-null   float64
#  37  GHGEmissionsIntensity(kgCO2e/ft2)                              3330 non-null   float64
#  38  DefaultData                                                    3339 non-null   object
#  39  Comment                                                        13 non-null     object
#  40  ComplianceStatus                                               3340 non-null   object
#  41  Outlier                                                        84 non-null     object
#  42  2010 Census Tracts                                             224 non-null    float64
#  43  Seattle Police Department Micro Community Policing Plan Areas  3338 non-null   float64
#  44  City Council Districts                                         213 non-null    float64
#  45  SPD Beats                                                      3338 non-null   float64
#  46  Zip Codes                                                      3340 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 1.2+ MB

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
# Out:
# 26512

# %%
# Impute the missing values with mean imputation
df = df.fillna(df.mean())

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
#14640
# Out:
# 14640

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   OSEBuildingID                                                  3340 non-null   int64
#  1   DataYear                                                       3340 non-null   int64
#  2   BuildingType                                                   3340 non-null   object
#  3   PrimaryPropertyType                                            3340 non-null   object
#  4   PropertyName                                                   3340 non-null   object
#  5   TaxParcelIdentificationNumber                                  3338 non-null   object
#  6   Location                                                       3340 non-null   object
#  7   CouncilDistrictCode                                            3340 non-null   int64
#  8   Neighborhood                                                   3340 non-null   object
#  9   YearBuilt                                                      3340 non-null   int64
#  10  NumberofBuildings                                              3340 non-null   int64
#  11  NumberofFloors                                                 3340 non-null   float64
#  12  PropertyGFATotal                                               3340 non-null   int64
#  13  PropertyGFAParking                                             3340 non-null   int64
#  14  PropertyGFABuilding(s)                                         3340 non-null   int64
#  15  ListOfAllPropertyUseTypes                                      3213 non-null   object
#  16  LargestPropertyUseType                                         3204 non-null   object
#  17  LargestPropertyUseTypeGFA                                      3340 non-null   float64
#  18  SecondLargestPropertyUseType                                   1559 non-null   object
#  19  SecondLargestPropertyUseTypeGFA                                3340 non-null   float64
#  20  ThirdLargestPropertyUseType                                    560 non-null    object
#  21  ThirdLargestPropertyUseTypeGFA                                 3340 non-null   float64
#  22  YearsENERGYSTARCertified                                       110 non-null    object
#  23  ENERGYSTARScore                                                3340 non-null   float64
#  24  SiteEUI(kBtu/sf)                                               3340 non-null   float64
#  25  SiteEUIWN(kBtu/sf)                                             3340 non-null   float64
#  26  SourceEUI(kBtu/sf)                                             3340 non-null   float64
#  27  SourceEUIWN(kBtu/sf)                                           3340 non-null   float64
#  28  SiteEnergyUse(kBtu)                                            3340 non-null   float64
#  29  SiteEnergyUseWN(kBtu)                                          3340 non-null   float64
#  30  SteamUse(kBtu)                                                 3340 non-null   float64
#  31  Electricity(kWh)                                               3340 non-null   float64
#  32  Electricity(kBtu)                                              3340 non-null   float64
#  33  NaturalGas(therms)                                             3340 non-null   float64
#  34  NaturalGas(kBtu)                                               3340 non-null   float64
#  35  OtherFuelUse(kBtu)                                             3340 non-null   float64
#  36  GHGEmissions(MetricTonsCO2e)                                   3340 non-null   float64
#  37  GHGEmissionsIntensity(kgCO2e/ft2)                              3340 non-null   float64
#  38  DefaultData                                                    3339 non-null   object
#  39  Comment                                                        13 non-null     object
#  40  ComplianceStatus                                               3340 non-null   object
#  41  Outlier                                                        84 non-null     object
#  42  2010 Census Tracts                                             3340 non-null   float64
#  43  Seattle Police Department Micro Community Policing Plan Areas  3340 non-null   float64
#  44  City Council Districts                                         3340 non-null   float64
#  45  SPD Beats                                                      3340 non-null   float64
#  46  Zip Codes                                                      3340 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 1.2+ MB

# %%
# Impute the missing values with mode for categorical variables
df = df.fillna(df.mode())

# %%
# Inspect missing values in the dataset
print(df.isnull().values.sum())
#14640
# Out:
# 14623

# %%
#sort the column
df=df.reindex(sorted(df.columns), axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   2010 Census Tracts                                             3340 non-null   float64
#  1   BuildingType                                                   3340 non-null   object
#  2   City Council Districts                                         3340 non-null   float64
#  3   Comment                                                        26 non-null     object
#  4   ComplianceStatus                                               3340 non-null   object
#  5   CouncilDistrictCode                                            3340 non-null   int64
#  6   DataYear                                                       3340 non-null   int64
#  7   DefaultData                                                    3339 non-null   object
#  8   ENERGYSTARScore                                                3340 non-null   float64
#  9   Electricity(kBtu)                                              3340 non-null   float64
#  10  Electricity(kWh)                                               3340 non-null   float64
#  11  GHGEmissions(MetricTonsCO2e)                                   3340 non-null   float64
#  12  GHGEmissionsIntensity(kgCO2e/ft2)                              3340 non-null   float64
#  13  LargestPropertyUseType                                         3204 non-null   object
#  14  LargestPropertyUseTypeGFA                                      3340 non-null   float64
#  15  ListOfAllPropertyUseTypes                                      3213 non-null   object
#  16  Location                                                       3340 non-null   object
#  17  NaturalGas(kBtu)                                               3340 non-null   float64
#  18  NaturalGas(therms)                                             3340 non-null   float64
#  19  Neighborhood                                                   3340 non-null   object
#  20  NumberofBuildings                                              3340 non-null   int64
#  21  NumberofFloors                                                 3340 non-null   float64
#  22  OSEBuildingID                                                  3340 non-null   int64
#  23  OtherFuelUse(kBtu)                                             3340 non-null   float64
#  24  Outlier                                                        85 non-null     object
#  25  PrimaryPropertyType                                            3340 non-null   object
#  26  PropertyGFABuilding(s)                                         3340 non-null   int64
#  27  PropertyGFAParking                                             3340 non-null   int64
#  28  PropertyGFATotal                                               3340 non-null   int64
#  29  PropertyName                                                   3340 non-null   object
#  30  SPD Beats                                                      3340 non-null   float64
#  31  Seattle Police Department Micro Community Policing Plan Areas  3340 non-null   float64
#  32  SecondLargestPropertyUseType                                   1560 non-null   object
#  33  SecondLargestPropertyUseTypeGFA                                3340 non-null   float64
#  34  SiteEUI(kBtu/sf)                                               3340 non-null   float64
#  35  SiteEUIWN(kBtu/sf)                                             3340 non-null   float64
#  36  SiteEnergyUse(kBtu)                                            3340 non-null   float64
#  37  SiteEnergyUseWN(kBtu)                                          3340 non-null   float64
#  38  SourceEUI(kBtu/sf)                                             3340 non-null   float64
#  39  SourceEUIWN(kBtu/sf)                                           3340 non-null   float64
#  40  SteamUse(kBtu)                                                 3340 non-null   float64
#  41  TaxParcelIdentificationNumber                                  3338 non-null   object
#  42  ThirdLargestPropertyUseType                                    561 non-null    object
#  43  ThirdLargestPropertyUseTypeGFA                                 3340 non-null   float64
#  44  YearBuilt                                                      3340 non-null   int64
#  45  YearsENERGYSTARCertified                                       111 non-null    object
#  46  Zip Codes                                                      3340 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 1.2+ MB

# %%
#drop the columns which has lot of missing values
df.drop(['Comment','Outlier','SecondLargestPropertyUseType','ThirdLargestPropertyUseType','YearsENERGYSTARCertified'
         'LargestPropertyUseType','Zip Codes','ListOfAllPropertyUseTypes','LargestPropertyUseType','TaxParcelIdentificationNumber','DefaultData'] ,axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3c6614c9d02e> in <module>
#       1 #drop the columns which has lot of missing values
# ----> 2 df.drop(['Comment','Outlier','SecondLargestPropertyUseType','ThirdLargestPropertyUseType','YearsENERGYSTARCertified'
#       3          'LargestPropertyUseType','Zip Codes','ListOfAllPropertyUseTypes','LargestPropertyUseType','TaxParcelIdentificationNumber','DefaultData'] ,axis=1, inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['YearsENERGYSTARCertifiedLargestPropertyUseType'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   2010 Census Tracts                                             3340 non-null   float64
#  1   BuildingType                                                   3340 non-null   object
#  2   City Council Districts                                         3340 non-null   float64
#  3   Comment                                                        26 non-null     object
#  4   ComplianceStatus                                               3340 non-null   object
#  5   CouncilDistrictCode                                            3340 non-null   int64
#  6   DataYear                                                       3340 non-null   int64
#  7   DefaultData                                                    3339 non-null   object
#  8   ENERGYSTARScore                                                3340 non-null   float64
#  9   Electricity(kBtu)                                              3340 non-null   float64
#  10  Electricity(kWh)                                               3340 non-null   float64
#  11  GHGEmissions(MetricTonsCO2e)                                   3340 non-null   float64
#  12  GHGEmissionsIntensity(kgCO2e/ft2)                              3340 non-null   float64
#  13  LargestPropertyUseType                                         3204 non-null   object
#  14  LargestPropertyUseTypeGFA                                      3340 non-null   float64
#  15  ListOfAllPropertyUseTypes                                      3213 non-null   object
#  16  Location                                                       3340 non-null   object
#  17  NaturalGas(kBtu)                                               3340 non-null   float64
#  18  NaturalGas(therms)                                             3340 non-null   float64
#  19  Neighborhood                                                   3340 non-null   object
#  20  NumberofBuildings                                              3340 non-null   int64
#  21  NumberofFloors                                                 3340 non-null   float64
#  22  OSEBuildingID                                                  3340 non-null   int64
#  23  OtherFuelUse(kBtu)                                             3340 non-null   float64
#  24  Outlier                                                        85 non-null     object
#  25  PrimaryPropertyType                                            3340 non-null   object
#  26  PropertyGFABuilding(s)                                         3340 non-null   int64
#  27  PropertyGFAParking                                             3340 non-null   int64
#  28  PropertyGFATotal                                               3340 non-null   int64
#  29  PropertyName                                                   3340 non-null   object
#  30  SPD Beats                                                      3340 non-null   float64
#  31  Seattle Police Department Micro Community Policing Plan Areas  3340 non-null   float64
#  32  SecondLargestPropertyUseType                                   1560 non-null   object
#  33  SecondLargestPropertyUseTypeGFA                                3340 non-null   float64
#  34  SiteEUI(kBtu/sf)                                               3340 non-null   float64
#  35  SiteEUIWN(kBtu/sf)                                             3340 non-null   float64
#  36  SiteEnergyUse(kBtu)                                            3340 non-null   float64
#  37  SiteEnergyUseWN(kBtu)                                          3340 non-null   float64
#  38  SourceEUI(kBtu/sf)                                             3340 non-null   float64
#  39  SourceEUIWN(kBtu/sf)                                           3340 non-null   float64
#  40  SteamUse(kBtu)                                                 3340 non-null   float64
#  41  TaxParcelIdentificationNumber                                  3338 non-null   object
#  42  ThirdLargestPropertyUseType                                    561 non-null    object
#  43  ThirdLargestPropertyUseTypeGFA                                 3340 non-null   float64
#  44  YearBuilt                                                      3340 non-null   int64
#  45  YearsENERGYSTARCertified                                       111 non-null    object
#  46  Zip Codes                                                      3340 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 1.2+ MB

# %%
print(df.isnull().values.sum())
# Out:
# 14623

# %%
df.drop=(["DefaultData","TaxParcelIdentificationNumber"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   2010 Census Tracts                                             3340 non-null   float64
#  1   BuildingType                                                   3340 non-null   object
#  2   City Council Districts                                         3340 non-null   float64
#  3   Comment                                                        26 non-null     object
#  4   ComplianceStatus                                               3340 non-null   object
#  5   CouncilDistrictCode                                            3340 non-null   int64
#  6   DataYear                                                       3340 non-null   int64
#  7   DefaultData                                                    3339 non-null   object
#  8   ENERGYSTARScore                                                3340 non-null   float64
#  9   Electricity(kBtu)                                              3340 non-null   float64
#  10  Electricity(kWh)                                               3340 non-null   float64
#  11  GHGEmissions(MetricTonsCO2e)                                   3340 non-null   float64
#  12  GHGEmissionsIntensity(kgCO2e/ft2)                              3340 non-null   float64
#  13  LargestPropertyUseType                                         3204 non-null   object
#  14  LargestPropertyUseTypeGFA                                      3340 non-null   float64
#  15  ListOfAllPropertyUseTypes                                      3213 non-null   object
#  16  Location                                                       3340 non-null   object
#  17  NaturalGas(kBtu)                                               3340 non-null   float64
#  18  NaturalGas(therms)                                             3340 non-null   float64
#  19  Neighborhood                                                   3340 non-null   object
#  20  NumberofBuildings                                              3340 non-null   int64
#  21  NumberofFloors                                                 3340 non-null   float64
#  22  OSEBuildingID                                                  3340 non-null   int64
#  23  OtherFuelUse(kBtu)                                             3340 non-null   float64
#  24  Outlier                                                        85 non-null     object
#  25  PrimaryPropertyType                                            3340 non-null   object
#  26  PropertyGFABuilding(s)                                         3340 non-null   int64
#  27  PropertyGFAParking                                             3340 non-null   int64
#  28  PropertyGFATotal                                               3340 non-null   int64
#  29  PropertyName                                                   3340 non-null   object
#  30  SPD Beats                                                      3340 non-null   float64
#  31  Seattle Police Department Micro Community Policing Plan Areas  3340 non-null   float64
#  32  SecondLargestPropertyUseType                                   1560 non-null   object
#  33  SecondLargestPropertyUseTypeGFA                                3340 non-null   float64
#  34  SiteEUI(kBtu/sf)                                               3340 non-null   float64
#  35  SiteEUIWN(kBtu/sf)                                             3340 non-null   float64
#  36  SiteEnergyUse(kBtu)                                            3340 non-null   float64
#  37  SiteEnergyUseWN(kBtu)                                          3340 non-null   float64
#  38  SourceEUI(kBtu/sf)                                             3340 non-null   float64
#  39  SourceEUIWN(kBtu/sf)                                           3340 non-null   float64
#  40  SteamUse(kBtu)                                                 3340 non-null   float64
#  41  TaxParcelIdentificationNumber                                  3338 non-null   object
#  42  ThirdLargestPropertyUseType                                    561 non-null    object
#  43  ThirdLargestPropertyUseTypeGFA                                 3340 non-null   float64
#  44  YearBuilt                                                      3340 non-null   int64
#  45  YearsENERGYSTARCertified                                       111 non-null    object
#  46  Zip Codes                                                      3340 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 1.2+ MB

# %%
print(df.isnull().values.sum())
# Out:
# 14623

# %%
# seaborn histogram 
#plt.figure(figsize=(25,255))
sns.catplot(x="BuildingType", kind="count",height=6, aspect=2,data=df)
#Catplot Python Seaborn: One Function to Rule All Plots With Categorical Variables
#Non-residential building are more in numbers

# %%
#seaborn Scatterplot
#(z-score )normalization is applied on "TotalGHGEmissions"
plt.figure(figsize=(15,7))
df["GHGEmissions(MetricTonsCO2e)"]=(df["GHGEmissions(MetricTonsCO2e)"]-df["GHGEmissions(MetricTonsCO2e)"].mean())/df["GHGEmissions(MetricTonsCO2e)"].std()
sns.scatterplot(x=df['BuildingType'], y=df['GHGEmissions(MetricTonsCO2e)'])
#NonResidentials buildings are higher in GHGEmissions(MetricTonsCO2e)

# %%
#simple feature scaling(range 0-1)
#xnew=xold/xmax
#seaborn Scatterplot
plt.figure(figsize=(15,7))
df["GHGEmissions(MetricTonsCO2e)"]=(df["GHGEmissions(MetricTonsCO2e)"])/df["GHGEmissions(MetricTonsCO2e)"].max()
sns.scatterplot(x=df['BuildingType'], y=df["GHGEmissions(MetricTonsCO2e)"])

# %%
#(z-score )normalization is applied on "TotalGHGEmissions"
plt.figure(figsize=(15,7))
df["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df["GHGEmissionsIntensity(kgCO2e/ft2)"]-df["GHGEmissionsIntensity(kgCO2e/ft2)"].mean())/df["GHGEmissionsIntensity(kgCO2e/ft2)"].std()
sns.scatterplot(x=df['BuildingType'], y=df['GHGEmissionsIntensity(kgCO2e/ft2)'])
#NonResidentials buildings are higher in GHGEmissions(MetricTonsCO2e)

# %%
df_nr=df[(df['BuildingType'] =='NonResidential') ]

# %%
df_nr.head()
# Out:
#    2010 Census Tracts    BuildingType  City Council Districts  \
# 0            123.0625  NonResidential                1.347418
# 1            123.0625  NonResidential                1.347418
# 2            123.0625  NonResidential                1.347418
# 3            123.0625  NonResidential                1.347418
# 4            123.0625  NonResidential                1.347418
#
#                                              Comment ComplianceStatus  \
# 0  Construction completed in mid 2015. The buildi...        Compliant
# 1  One of two office buildings on McKinstry's cam...        Compliant
# 2  Part of McKinstry's campus, property includes ...        Compliant
# 3  Part of McKinstry's campus, property operates ...        Compliant
# 4  Part of McKinstry's campus, the office space f...        Compliant
#
#    CouncilDistrictCode  DataYear DefaultData  ENERGYSTARScore  \
# 0                    7      2015          No             65.0
# 1                    7      2015          No             51.0
# 2                    7      2015         Yes             18.0
# 3                    7      2015          No              1.0
# 4                    7      2015          No             67.0
#
#    Electricity(kBtu)  ...  SiteEnergyUseWN(kBtu)  SourceEUI(kBtu/sf)  \
# 0          3686160.0  ...              7097539.0               173.5
# 1          3905411.0  ...              8765788.0               191.3
# 2         49762435.0  ...             75506272.0               242.7
# 3          2769023.0  ...             28363444.0               636.3
# 4          6066245.0  ...             15078243.0               228.8
#
#    SourceEUIWN(kBtu/sf) SteamUse(kBtu)  TaxParcelIdentificationNumber  \
# 0                 175.1      2023032.0                      659000030
# 1                 195.2            0.0                      659000220
# 2                 246.5     19660404.0                      659000475
# 3                 643.2     23458518.0                      659000640
# 4                 227.1            0.0                      659000970
#
#   ThirdLargestPropertyUseType ThirdLargestPropertyUseTypeGFA  YearBuilt  \
# 0                Retail Store                   10755.708929       1927
# 1                  Restaurant                    4622.000000       1996
# 2               Swimming Pool                       0.000000       1969
# 3                         NaN                   10755.708929       1926
# 4               Swimming Pool                       0.000000       1980
#
#    YearsENERGYSTARCertified Zip Codes
# 0                      2016     18081
# 1                       NaN     18081
# 2                       NaN     18081
# 3                       NaN     18081
# 4                       NaN     19576
#
# [5 rows x 47 columns]

# %%
df_nr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1461 entries, 0 to 3334
# Data columns (total 47 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   2010 Census Tracts                                             1461 non-null   float64
#  1   BuildingType                                                   1461 non-null   object
#  2   City Council Districts                                         1461 non-null   float64
#  3   Comment                                                        16 non-null     object
#  4   ComplianceStatus                                               1461 non-null   object
#  5   CouncilDistrictCode                                            1461 non-null   int64
#  6   DataYear                                                       1461 non-null   int64
#  7   DefaultData                                                    1460 non-null   object
#  8   ENERGYSTARScore                                                1461 non-null   float64
#  9   Electricity(kBtu)                                              1461 non-null   float64
#  10  Electricity(kWh)                                               1461 non-null   float64
#  11  GHGEmissions(MetricTonsCO2e)                                   1461 non-null   float64
#  12  GHGEmissionsIntensity(kgCO2e/ft2)                              1461 non-null   float64
#  13  LargestPropertyUseType                                         1400 non-null   object
#  14  LargestPropertyUseTypeGFA                                      1461 non-null   float64
#  15  ListOfAllPropertyUseTypes                                      1404 non-null   object
#  16  Location                                                       1461 non-null   object
#  17  NaturalGas(kBtu)                                               1461 non-null   float64
#  18  NaturalGas(therms)                                             1461 non-null   float64
#  19  Neighborhood                                                   1461 non-null   object
#  20  NumberofBuildings                                              1461 non-null   int64
#  21  NumberofFloors                                                 1461 non-null   float64
#  22  OSEBuildingID                                                  1461 non-null   int64
#  23  OtherFuelUse(kBtu)                                             1461 non-null   float64
#  24  Outlier                                                        30 non-null     object
#  25  PrimaryPropertyType                                            1461 non-null   object
#  26  PropertyGFABuilding(s)                                         1461 non-null   int64
#  27  PropertyGFAParking                                             1461 non-null   int64
#  28  PropertyGFATotal                                               1461 non-null   int64
#  29  PropertyName                                                   1461 non-null   object
#  30  SPD Beats                                                      1461 non-null   float64
#  31  Seattle Police Department Micro Community Policing Plan Areas  1461 non-null   float64
#  32  SecondLargestPropertyUseType                                   764 non-null    object
#  33  SecondLargestPropertyUseTypeGFA                                1461 non-null   float64
#  34  SiteEUI(kBtu/sf)                                               1461 non-null   float64
#  35  SiteEUIWN(kBtu/sf)                                             1461 non-null   float64
#  36  SiteEnergyUse(kBtu)                                            1461 non-null   float64
#  37  SiteEnergyUseWN(kBtu)                                          1461 non-null   float64
#  38  SourceEUI(kBtu/sf)                                             1461 non-null   float64
#  39  SourceEUIWN(kBtu/sf)                                           1461 non-null   float64
#  40  SteamUse(kBtu)                                                 1461 non-null   float64
#  41  TaxParcelIdentificationNumber                                  1461 non-null   object
#  42  ThirdLargestPropertyUseType                                    303 non-null    object
#  43  ThirdLargestPropertyUseTypeGFA                                 1461 non-null   float64
#  44  YearBuilt                                                      1461 non-null   int64
#  45  YearsENERGYSTARCertified                                       83 non-null     object
#  46  Zip Codes                                                      1461 non-null   int64
# dtypes: float64(23), int64(9), object(15)
# memory usage: 547.9+ KB

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['Electricity(kBtu)'], y=df["GHGEmissions(MetricTonsCO2e)"])

# %%
#line plot 
df["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df["GHGEmissionsIntensity(kgCO2e/ft2)"])/df["GHGEmissionsIntensity(kgCO2e/ft2)"].max()
plt.figure(figsize=(15,8))
sns.lineplot(x='BuildingType',y='GHGEmissionsIntensity(kgCO2e/ft2)', data=df)
#GHGEmissionsIntensity is highest in Campus

# %%
#Box plot
plt.figure(figsize=(15,10))
#df["GHGEmissions(MetricTonsCO2e)"]=(df["GHGEmissions(MetricTonsCO2e)"]-df["GHGEmissions(MetricTonsCO2e)"].mean())/df["GHGEmissions(MetricTonsCO2e)"].std()
df["GHGEmissions(MetricTonsCO2e)"]=(df["GHGEmissions(MetricTonsCO2e)"])/df["GHGEmissions(MetricTonsCO2e)"].max()
sns.boxplot(y ='GHGEmissions(MetricTonsCO2e)',data= df, x= 'BuildingType')
plt.xlabel('BuildingType')
## Multifamily MR (5-9),SPS-District K-12 , Multifamily LR (1-4), have almost same mean
# Out:
# Text(0.5, 0, 'BuildingType')

# %%
df["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df["GHGEmissionsIntensity(kgCO2e/ft2)"])/df["GHGEmissionsIntensity(kgCO2e/ft2)"].max()
plt.figure(figsize=(15,8))
sns.boxplot(x='BuildingType',y='GHGEmissionsIntensity(kgCO2e/ft2)', data=df )
plt.xlabel('BuildingType')
# Out:
# Text(0.5, 0, 'BuildingType')

# %%
# NonResidential and Multifamily MR have same mean value
#Multifamily Lr and multifamily Hr have same mean distribution

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df_nr.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
drop_list=["DataYear","2010 Census Tracts","City Council Districts","Electricity(kWh)","NaturalGas(therms)","PropertyGFABuilding(s)",
          "SiteEUI(kBtu/sf)","SiteEnergyUse(kBtu)","SourceEUI(kBtu/sf)","LargestPropertyUseTypeGFA","SecondLargestPropertyUseTypeGFA",
           "Seattle Police Department Micro Community Policing Plan Areas","NumberofFloors","SiteEUIWN(kBtu/sf)","PropertyGFAParking",
          "DefaultData","YearBuilt","SPD Beats","ThirdLargestPropertyUseTypeGFA","NumberofBuildings","OSEBuildingID","CouncilDistrictCode"]

# %%
df_nr_1=df_nr.drop(drop_list,axis=1)
#df_2015_x=df_2015.drop(drop_list,axis=1)
#df_1=df.drop(drop_list,axis=1)

# %%
df_nr_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1461 entries, 0 to 3334
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   BuildingType                       1461 non-null   object
#  1   Comment                            16 non-null     object
#  2   ComplianceStatus                   1461 non-null   object
#  3   ENERGYSTARScore                    1461 non-null   float64
#  4   Electricity(kBtu)                  1461 non-null   float64
#  5   GHGEmissions(MetricTonsCO2e)       1461 non-null   float64
#  6   GHGEmissionsIntensity(kgCO2e/ft2)  1461 non-null   float64
#  7   LargestPropertyUseType             1400 non-null   object
#  8   ListOfAllPropertyUseTypes          1404 non-null   object
#  9   Location                           1461 non-null   object
#  10  NaturalGas(kBtu)                   1461 non-null   float64
#  11  Neighborhood                       1461 non-null   object
#  12  OtherFuelUse(kBtu)                 1461 non-null   float64
#  13  Outlier                            30 non-null     object
#  14  PrimaryPropertyType                1461 non-null   object
#  15  PropertyGFATotal                   1461 non-null   int64
#  16  PropertyName                       1461 non-null   object
#  17  SecondLargestPropertyUseType       764 non-null    object
#  18  SiteEnergyUseWN(kBtu)              1461 non-null   float64
#  19  SourceEUIWN(kBtu/sf)               1461 non-null   float64
#  20  SteamUse(kBtu)                     1461 non-null   float64
#  21  TaxParcelIdentificationNumber      1461 non-null   object
#  22  ThirdLargestPropertyUseType        303 non-null    object
#  23  YearsENERGYSTARCertified           83 non-null     object
#  24  Zip Codes                          1461 non-null   int64
# dtypes: float64(9), int64(2), object(14)
# memory usage: 296.8+ KB

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df_nr_1.corr(), annot=True, linewidths=.8, fmt= '.1f',ax=ax)

# %%
##To select  numeric types and object types
df_nr_1_num=df_nr_1.select_dtypes(np.number)
df_nr_1_obj=df_nr_1.select_dtypes('object')

# %%
df_nr_1_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1461 entries, 0 to 3334
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ENERGYSTARScore                    1461 non-null   float64
#  1   Electricity(kBtu)                  1461 non-null   float64
#  2   GHGEmissions(MetricTonsCO2e)       1461 non-null   float64
#  3   GHGEmissionsIntensity(kgCO2e/ft2)  1461 non-null   float64
#  4   NaturalGas(kBtu)                   1461 non-null   float64
#  5   OtherFuelUse(kBtu)                 1461 non-null   float64
#  6   PropertyGFATotal                   1461 non-null   int64
#  7   SiteEnergyUseWN(kBtu)              1461 non-null   float64
#  8   SourceEUIWN(kBtu/sf)               1461 non-null   float64
#  9   SteamUse(kBtu)                     1461 non-null   float64
#  10  Zip Codes                          1461 non-null   int64
# dtypes: float64(9), int64(2)
# memory usage: 137.0 KB

# %%
df["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df["GHGEmissionsIntensity(kgCO2e/ft2)"]-df["GHGEmissionsIntensity(kgCO2e/ft2)"].mean())/df["GHGEmissionsIntensity(kgCO2e/ft2)"].std()

# %%
plt.figure(figsize=(5,5))
df["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df["GHGEmissionsIntensity(kgCO2e/ft2)"]-df["GHGEmissionsIntensity(kgCO2e/ft2)"].mean())/df["GHGEmissionsIntensity(kgCO2e/ft2)"].std()
df["Electricity(kBtu)"]=(df["Electricity(kBtu)"]-df["Electricity(kBtu)"].mean())/df["Electricity(kBtu)"].std()
plt.scatter(df["Electricity(kBtu)"],df["GHGEmissionsIntensity(kgCO2e/ft2)"],  color='blue')
plt.xlabel("Electricity(kBtu)")
plt.ylabel("GHGEmissionsIntensity(kgCO2e/ft2)")
plt.show()

# %%
plt.scatter(df["SiteEnergyUseWN(kBtu)"],df["GHGEmissions(MetricTonsCO2e)"],  color='blue')
plt.xlabel("SiteEnergyUseWN(kBtu)")
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.show()

# %%
plt.scatter(df["NaturalGas(kBtu)"],df["GHGEmissions(MetricTonsCO2e)"],  color='blue')
plt.xlabel("NaturalGas(kBtu)")
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.show()

# %%
plt.scatter(df["PropertyGFATotal"],df["GHGEmissions(MetricTonsCO2e)"],  color='blue')
plt.xlabel("PropertyGFATotal")
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.show()

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (df["Electricity(kBtu)"].values, df["GHGEmissions(MetricTonsCO2e)"].values)
plt.plot(x_data, y_data, 'ro')
plt.ylabel('GHGEmissions(MetricTonsCO2e)')
plt.xlabel('Electricity(kBtu)')
plt.show()

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (df["Electricity(kBtu)"].values, df["GHGEmissions(MetricTonsCO2e)"].values)
plt.plot(x_data, y_data, 'ro')
plt.ylabel('GHGEmissions(MetricTonsCO2e)')
plt.xlabel('Electricity(kBtu)')
plt.show()

# %%
(df['OtherFuelUse(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.005735321665209337

# %%
(df["ENERGYSTARScore"]).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# -0.08157225245941788

# %%
(df['Electricity(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.6702520359853559

# %%
(df['NaturalGas(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.6173087683481827

# %%
(df['OtherFuelUse(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.005735321665209337

# %%
(df['PropertyGFATotal']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.48797969400553975

# %%
(df['SiteEnergyUseWN(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.8849906310991194

# %%
(df['SourceEUIWN(kBtu/sf)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.26150255760310426

# %%
(df['SteamUse(kBtu)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.8093144345306517

# %%
(df['GHGEmissionsIntensity(kgCO2e/ft2)']).corr(df['GHGEmissions(MetricTonsCO2e)'])
# Out:
# 0.39906077444767085

# %%
import pandas
from sklearn import linear_model

df =df_nr_1_num
X=df_nr_1_num[["Electricity(kBtu)","NaturalGas(kBtu)","SiteEnergyUseWN(kBtu)","PropertyGFATotal",
               "SteamUse(kBtu)"]]
y=df_nr_1_num['GHGEmissions(MetricTonsCO2e)']
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state=1)

# %%
#Fitting the MLR model to the training set:  
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Predicting the Test set result;  
y_pred= regressor.predict(x_test)

# %%
print ('Coefficients: ',regressor.coef_)
print ('Intercept: ' ,regressor.intercept_)
# Out:
# Coefficients:  [ 5.95071033e-10  4.53358681e-09 -3.15855338e-15  6.22382030e-15
#   6.58893040e-09]
# Intercept:  -0.009397864796179978

# %%
print('Train Score: ', regressor.score(x_train, y_train))  
print('Test Score: ', regressor.score(x_test, y_test))
# Out:
# Train Score:  0.9999999999717903
# Test Score:  0.9999999999814411

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
#print('Mean Square error:')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-016ec386e3f2> in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 mean_squared_error(y_test, y_pred)
#       3 #print('Mean Square error:')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     254         y_true, y_pred, multioutput)
#     255     check_consistent_length(y_true, y_pred, sample_weight)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     254     uniques = np.unique(lengths)
#     255     if len(uniques) > 1:
# --> 256         raise ValueError("Found input variables with inconsistent numbers of"
#     257                          " samples: %r" % [int(l) for l in lengths])
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [293, 1168]

# %%
import seaborn as sns
# %matplotlib inline 
width =10
height =10
plt.figure(figsize=(width, height))

y_pred=regressor.predict(x_train)
ax1 = sns.distplot(df['GHGEmissions(MetricTonsCO2e)'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for TotalGHGEmissions')
plt.xlabel('GHGEmissions(MetricTonsCO2e)')
plt.ylabel('Proportion of TotalGHGEmissions')

plt.show()
plt.close()

# %%
#using Multiple Linear Regression Model we can(nearly) predict the emissions of buildings(nonresidential) whose
#emissions have not yet been measured.
